# %% [markdown]
# <a href="https://colab.research.google.com/github/krishchat/DataVisualizationBasics/blob/main/Data_Visualization_EDA_Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/PGP - AI ML Course/MLS 2 - Data Visualization - EDA - Titanic/Titanic+Data+Set.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df_1 = df.drop(['Cabin'], axis = 1)

# %%
df_1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
abs(df.corr()[abs(df.corr()['Pclass']) > 0.5]['Pclass'])
# Out:
# Pclass    1.0000
# Fare      0.5495
# Name: Pclass, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.figure(figsize = (20,7))
sns.heatmap(data = df[['Pclass', 'Fare', 'Survived', 'Parch', 'Age']].corr(),annot = True );

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.figure(figsize = (20,7))
sns.stripplot(data = df, x= 'Age', y='Sex', hue = 'Survived');

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

#plt.figure(figsize = (20,7))
sns.histplot(data = df['Parch']);

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.figure(figsize =(8,7))
sns.countplot(data = df, x= 'Pclass', hue='Survived');

# %%
df.groupby(['Pclass'])['Survived'].value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.countplot(data = df, x='Embarked', hue= 'Survived');

#sns.countplot(data = df, x='Embarked');

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.boxplot(data = df, x='Fare', y='Sex');
